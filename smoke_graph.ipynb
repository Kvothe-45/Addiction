# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_smoke_drink = pd.read_csv("BDD_initial/addiction_population_data.csv", sep=",", index_col=0)
data_smoke_drink.head()
# Out:
#                 name  age  gender       country         city education_level  \
# id
# 1      Michael Bates   66   Other         Yemen  Martinmouth       Secondary
# 2     Brian Thompson   29    Male  Saudi Arabia  Harperhaven         Primary
# 3      Steven Little   75    Male          Togo     Chanport    Postgraduate
# 4    Michael Mathews   35   Other          Togo   North Cory      University
# 5   Nicholas Sanchez   38  Female       Morocco   Danielberg         College
#
#    employment_status  annual_income_usd     marital_status  children_count  \
# id
# 1            Student              45595            Married               3
# 2      Self-Employed             145842             Single               4
# 3         Unemployed             162480             Single               5
# 4         Unemployed              16023  In a relationship               3
# 5      Self-Employed              62933  In a relationship               0
#
# ...

# %%
ordre = ['Secondary', 'Primary', 'Postgraduate', 'University', 'College',
       'High School']
fig, ax = plt.subplots()
sns.violinplot(
    data=data_smoke_drink,
    x="education_level",
    y="sleep_hours",
    order=ordre,
    palette="Set2",
    inner="quartile",
    ax=ax,
)
ax.set_title("Heures de sommeil par niveau académique")
ax.set_xlabel("Niveau académique")
ax.set_ylabel("Heures sommeils par nuit")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sidsm\AppData\Local\Temp\ipykernel_21476\569390431.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(

# %%
fig = plt.figure()
ax = sns.barplot(data=data_smoke_drink, x="education_level", y="annual_income_usd", hue="addict_smoke", estimator=np.mean, ci=95)
ax.set_title("Revenu annuel moyen par niveau académique et addiction au tabac")
plt.show()
# Out:
# C:\Users\sidsm\AppData\Local\Temp\ipykernel_21476\3768613072.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   ax = sns.barplot(data=data_smoke_drink, x="education_level", y="annual_income_usd", hue="addict_smoke", estimator=np.mean, ci=95)

# %%
fig = plt.figure()
ax = sns.regplot(data=data_smoke_drink, x="bmi", y="sleep_hours", ci=95, scatter_kws={"alpha":0.6})
ax.set_title("Régression linéaire (IC 95%) — iris")
plt.show()

# %%
fig = plt.figure()
ax = sns.scatterplot(data=data_smoke_drink, x="annual_income_usd", y="sleep_hours", hue="addict_smoke")
plt.show()

# %%
fig = plt.figure()
ax = sns.barplot(data=data_smoke_drink, x="children_count", y="annual_income_usd", ci=95, estimator=np.mean, hue="addict_smoke")
ax.set_title("cigarettes fumées par jour en fonction du nombre d'enfants")
plt.show()
# Out:
# C:\Users\sidsm\AppData\Local\Temp\ipykernel_21476\2112279358.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   ax = sns.barplot(data=data_smoke_drink, x="children_count", y="annual_income_usd", ci=95, estimator=np.mean, hue="addict_smoke")

# %%
fig = plt.figure()
ax = sns.barplot(data=data_smoke_drink, x="marital_status", y="smokes_per_day", ci=95, estimator=np.mean, hue="addict_smoke")
ax.set_title("cigarettes fumées par jour en fonction du nombre d'enfants")
plt.show()
# Out:
# C:\Users\sidsm\AppData\Local\Temp\ipykernel_21476\1126243111.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   ax = sns.barplot(data=data_smoke_drink, x="marital_status", y="smokes_per_day", ci=95, estimator=np.mean, hue="addict_smoke")

# %%
fig = plt.figure()
ax = sns.barplot(data=data_smoke_drink, x="marital_status", y="annual_income_usd", ci=95, estimator=np.mean, hue="addict_smoke")
ax.set_title("cigarettes fumées par jour en fonction du nombre d'enfants")
plt.show()
# Out:
# C:\Users\sidsm\AppData\Local\Temp\ipykernel_21476\1850042600.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   ax = sns.barplot(data=data_smoke_drink, x="marital_status", y="annual_income_usd", ci=95, estimator=np.mean, hue="addict_smoke")

# %%
fig = plt.figure()
ax = sns.barplot(data=data_smoke_drink, x="smokes_per_day", y="drinks_per_week", ci=95, estimator=np.mean, hue="addict_smoke")
ax.set_title("cigarettes fumées par jour en fonction du nombre d'enfants")
plt.show()
# Out:
# C:\Users\sidsm\AppData\Local\Temp\ipykernel_21476\1824937729.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   ax = sns.barplot(data=data_smoke_drink, x="smokes_per_day", y="drinks_per_week", ci=95, estimator=np.mean, hue="addict_smoke")

# %%
fig = plt.figure()
ax = sns.barplot(data=data_smoke_drink, x="attempts_to_quit_smoking", y="age_started_smoking", ci=95, estimator=np.mean, hue="children_count")
ax.set_title("cigarettes fumées par jour en fonction du nombre d'enfants")
plt.show()
# Out:
# C:\Users\sidsm\AppData\Local\Temp\ipykernel_21476\358592957.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   ax = sns.barplot(data=data_smoke_drink, x="attempts_to_quit_smoking", y="age_started_smoking", ci=95, estimator=np.mean, hue="children_count")

# %%
fig = plt.figure()
ax = sns.barplot(data=data_smoke_drink, x="attempts_to_quit_smoking", y="children_count", ci=95, estimator=np.mean, hue="addict_smoke")
ax.set_title("cigarettes fumées par jour en fonction du nombre d'enfants")
plt.show()
# Out:
# C:\Users\sidsm\AppData\Local\Temp\ipykernel_21476\2382655628.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   ax = sns.barplot(data=data_smoke_drink, x="attempts_to_quit_smoking", y="children_count", ci=95, estimator=np.mean, hue="addict_smoke")

# %%
data_smoke_drink.country.value_counts()
#Trop de pays différents, on ne peut pas utiliser cette variable pour la suite de nos analyses.
# Out:
# country
# Korea                       29
# Saudi Arabia                28
# Congo                       28
# Central African Republic    22
# Haiti                       22
#                             ..
# Seychelles                   5
# Kazakhstan                   5
# Singapore                    5
# Colombia                     4
# Norfolk Island               3
# Name: count, Length: 243, dtype: int64

# %%
fig = plt.figure()
ax = sns.barplot(data=data_smoke_drink, x="addict_smoke", y="annual_income_usd", ci=95, estimator=np.mean, hue="education_level")
ax.legend(loc="lower left", title="Niveau académique")  
plt.show()
# Out:
# C:\Users\sidsm\AppData\Local\Temp\ipykernel_21476\1425509055.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   ax = sns.barplot(data=data_smoke_drink, x="addict_smoke", y="annual_income_usd", ci=95, estimator=np.mean, hue="education_level")

# %%
data_heat = data_smoke_drink[["age", "bmi", "sleep_hours", "smokes_per_day", "age_started_smoking", "attempts_to_quit_smoking", "children_count", "annual_income_usd", "drinks_per_week", "age_started_drinking"]]
sns.heatmap(data_heat.corr(), annot=True, cmap="coolwarm", linewidths=0.5)
# Out:
# <Axes: >

# %%
fig = plt.figure()
ax = sns.barplot(data=data_smoke_drink, x="addict_smoke", y="has_health_issues", ci=95, estimator=np.mean, hue="exercise_frequency")
ax.legend(loc="lower left", title="Niveau académique")  
plt.show()
# Out:
# C:\Users\sidsm\AppData\Local\Temp\ipykernel_25388\3636027402.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   ax = sns.barplot(data=data_smoke_drink, x="addict_smoke", y="has_health_issues", ci=95, estimator=np.mean, hue="exercise_frequency")

# %%
from collections import Counter
from numpy.random import RandomState
from sklearn.datasets import make_classification
from imblearn.over_sampling import SMOTENC
X, y = make_classification(n_classes=2, class_sep=2,
weights=[0.1, 0.9], n_informative=3, n_redundant=1, flip_y=0,
n_features=20, n_clusters_per_class=1, n_samples=1000, random_state=10)
print(f'Original dataset shape {X.shape}')
print(f'Original dataset samples per class {Counter(y)}')
# simulate the 2 last columns to be categorical features
X[:, -2:] = RandomState(10).randint(0, 4, size=(1000, 2))
sm = SMOTENC(random_state=42, categorical_features=[18, 19])
X_res, y_res = sm.fit_resample(X, y)
print(f'Resampled dataset samples per class {Counter(y_res)}')
# Out:
# Original dataset shape (1000, 20)
# Original dataset samples per class Counter({np.int64(1): 900, np.int64(0): 100})
# Resampled dataset samples per class Counter({np.int64(0): 900, np.int64(1): 900})

# %%
X, y = make_classification(n_classes=2, class_sep=2,
weights=[0.1, 0.9], n_informative=3, n_redundant=1, flip_y=0,
n_features=20, n_clusters_per_class=1, n_samples=1000, random_state=10)
print(f'Original dataset shape {X.shape}')
print(f'Original dataset samples per class {Counter(y)}')
# simulate the 2 last columns to be categorical features
X[:, -2:] = RandomState(10).randint(0, 4, size=(1000, 2))
sm = SMOTENC(random_state=42, categorical_features=[18, 19])
X_res, y_res = sm.fit_resample(X, y)
print(f'Resampled dataset samples per class {Counter(y_res)}')
